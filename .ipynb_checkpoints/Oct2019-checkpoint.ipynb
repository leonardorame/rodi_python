# %%
# %run 'funciones.ipynb'
current=60
trades=[
    # Trades Reales
    {"date": "2019-08-13", "type": "CALL", "base": 150, "price": 14.8, "qty": -40},    
    {"date": "2019-08-13", "type": "PUT", "base": 126, "price": 29.60, "qty": -40}, 

    {"date": "2019-08-14", "type": "CALL", "base": 171, "price": 4.97, "qty": -12},
    {"date": "2019-08-14", "type": "PUT", "base": 126, "price": 29.39, "qty": 40},  # Me confundí, boludo!   
    {"date": "2019-08-14", "type": "PUT", "base": 126, "price": 26.27, "qty": -40}, #
    {"date": "2019-08-14", "type": "CALL", "base": 150, "price": 8.07, "qty": 40},    

    {"date": "2019-08-15", "type": "CALL", "base": 171, "price": 4.06, "qty": 12},     
    {"date": "2019-08-15", "type": "PUT", "base": 126, "price": 23.31, "qty": 40}, 
    {"date": "2019-08-15", "type": "CALL", "base": 150, "price": 8.12, "qty": -40}, 
    
    {"date": "2019-08-16", "type": "CALL", "base": 126, "price": 14.19, "qty": 20},             
    {"date": "2019-08-16", "type": "PUT", "base": 126, "price": 24.42, "qty": -40}, 
    
    {"date": "2019-08-19", "type": "CALL", "base": 111, "price": 11.89, "qty": -40}, 
    {"date": "2019-08-19", "type": "PUT", "base": 93, "price": 14.41, "qty": -40},  
    
    {"date": "2019-08-21", "type": "PUT", "base": 126, "price": 42.7, "qty": 40}, # Me ejercieron      

    {"date": "2019-08-22", "type": "CALL", "base": 111, "price": 10.13, "qty": 40},
    {"date": "2019-08-22", "type": "PUT", "base": 93, "price": 13.58, "qty": 40},       
    {"date": "2019-08-22", "type": "CALL", "base": 111, "price": 8.92, "qty": -30},
    {"date": "2019-08-22", "type": "PUT", "base": 99, "price": 17.23, "qty": 20},       
    {"date": "2019-08-22", "type": "PUT", "base": 80, "price": 6.91, "qty": -10},  
    
    {"date": "2019-08-23", "type": "CALL", "base": 111, "price": 4.86, "qty": 15},             
    {"date": "2019-08-23", "type": "CALL", "base": 93, "price": 9.98, "qty": 15},       
    {"date": "2019-08-23", "type": "PUT", "base": 85, "price": 9.63, "qty": 7},
    {"date": "2019-08-23", "type": "PUT", "base": 80, "price": 8.13, "qty": -37}, 
    
    {"date": "2019-08-26", "type": "CALL", "base": 111, "price": 3.45, "qty":-25},      
    {"date": "2019-08-26", "type": "CALL", "base": 93, "price": 7.87, "qty": 15},      
    {"date": "2019-08-26", "type": "CALL", "base": 93, "price": 7.89, "qty": -10},             
    {"date": "2019-08-26", "type": "CALL", "base": 87, "price": 9.63, "qty": 15}, 
    {"date": "2019-08-26", "type": "CALL", "base": 80, "price": 13.38, "qty": 25},    
    {"date": "2019-08-26", "type": "CALL", "base": 87, "price": 9.97, "qty": -25}, 
    {"date": "2019-08-26", "type": "CALL", "base": 99, "price": 6.08, "qty":10},      
    {"date": "2019-08-26", "type": "CALL", "base": 80, "price": 12.83, "qty": -10}, 
    
    {"date": "2019-08-27", "type": "CALL", "base": 126, "price": 1.22, "qty":40}, 
    {"date": "2019-08-27", "type": "CALL", "base": 87, "price": 7.60, "qty":20},
    
    {"date": "2019-08-28", "type": "PUT", "base": 85, "price": 15.20, "qty":15},
    {"date": "2019-08-28", "type": "PUT", "base": 63, "price": 5.53, "qty":-30}, 
    
    {"date": "2019-08-29", "type": "PUT", "base": 81, "price": 14.09, "qty": 25},
    {"date": "2019-08-29", "type": "CALL", "base": 111, "price": 2.43, "qty": 30},        
    {"date": "2019-08-29", "type": "CALL", "base": 75, "price": 13.17, "qty":10}, 
    {"date": "2019-08-29", "type": "CALL", "base": 99, "price": 4.32, "qty":-65},         
    {"date": "2019-08-29", "type": "CALL", "base": 93, "price": 5.33, "qty": -25},        
    {"date": "2019-08-29", "type": "CALL", "base": 63, "price": 18.24, "qty":5},  
    {"date": "2019-08-29", "type": "PUT", "base": 60, "price": 5.53, "qty": -10},

    {"date": "2019-08-30", "type": "PUT", "base": 63, "price": 7.79, "qty": -18},      
    {"date": "2019-08-30", "type": "CALL", "base": 111, "price": 2.42, "qty": -30},    
    {"date": "2019-08-30", "type": "CALL", "base": 63, "price": 16.89, "qty": 15},             
    {"date": "2019-08-30", "type": "CALL", "base": 102, "price": 2.96, "qty": -30},  
    {"date": "2019-08-30", "type": "CALL", "base": 90, "price": 4.44, "qty": -20},       
    {"date": "2019-08-30", "type": "CALL", "base": 111, "price": 2.08, "qty": 40},
    
    {"date": "2019-09-02", "type": "PUT", "base": 87, "price": 22.69, "qty": -25},     
    {"date": "2019-09-02", "type": "CALL", "base": 93, "price": 5.37, "qty": 20}, 
    {"date": "2019-09-02", "type": "CALL", "base": 63, "price": 18.35, "qty": -20},      
    {"date": "2019-09-02", "type": "CALL", "base": 99, "price": 3.90, "qty": 30},             

    {"date": "2019-09-03", "type": "CALL", "base": 90, "price": 3.85, "qty": 20}, 
    
    {"date": "2019-09-04", "type": "CALL", "base": 150, "price": 0.53, "qty": 25},     

    {"date": "2019-09-06", "type": "CALL", "base": 120, "price": 1.66, "qty": -100},
    {"date": "2019-09-06", "type": "CALL", "base": 99, "price": 3.55, "qty": 20},

    {"date": "2019-09-10", "type": "CALL", "base": 75, "price": 11.85, "qty": 40},    
    {"date": "2019-09-10", "type": "CALL", "base": 90, "price": 5.25, "qty": -26},    
 
    {"date": "2019-09-11", "type": "CALL", "base": 90, "price": 4.25, "qty": -50},    
    {"date": "2019-09-11", "type": "CALL", "base": 90, "price": 4.50, "qty": -10},    
    {"date": "2019-09-11", "type": "CALL", "base": 120, "price": 0.80, "qty": 50},        
    {"date": "2019-09-11", "type": "CALL", "base": 75, "price": 11.10, "qty": -30},
    {"date": "2019-09-11", "type": "CALL", "base": 150, "price": 0.25, "qty": 15},        
    {"date": "2019-09-11", "type": "CALL", "base": 99, "price": 2.35, "qty": 5},
    {"date": "2019-09-11", "type": "PUT", "base": 87, "price": 15, "qty": 10},

    {"date": "2019-09-12", "type": "PUT", "base": 63, "price": 4.39, "qty": 20},        
    {"date": "2019-09-12", "type": "PUT", "base": 63, "price": 3.95, "qty": 10},        
    {"date": "2019-09-12", "type": "PUT", "base": 60, "price": 3.20, "qty": 10},        
    {"date": "2019-09-12", "type": "PUT", "base": 80, "price": 9.2, "qty": -10},
    {"date": "2019-09-12", "type": "PUT", "base": 87, "price": 14.5, "qty":  15},

    {"date": "2019-09-13", "type": "CALL", "base": 102, "price": 2.40, "qty": 20},      
    {"date": "2019-09-13", "type": "CALL", "base": 111, "price": 1.60, "qty": 50},      
    {"date": "2019-09-13", "type": "CALL", "base": 93, "price": 4.80, "qty": 82},      
    {"date": "2019-09-13", "type": "CALL", "base": 90, "price": 5.10, "qty":  18},      

    {"date": "2019-09-17", "type": "PUT", "base": 75, "price": 6.00, "qty":  9},    
    {"date": "2019-09-17", "type": "PUT", "base": 80, "price": 8.50, "qty":  10},       
    {"date": "2019-09-17", "type": "PUT", "base": 63, "price": 2.60, "qty": -40},        

    {"date": "2019-09-18", "type": "PUT", "base": 80, "price": 7.1, "qty": -30},        
    {"date": "2019-09-18", "type": "CALL", "base": 93, "price": 4.20, "qty": -80},        

    {"date": "2019-09-19", "type": "CALL", "base": 75, "price": 11.35, "qty": -12}, # verificada
    {"date": "2019-09-19", "type": "CALL", "base": 87, "price": 6.20, "qty": 20},        
    
    {"date": "2019-09-20", "type": "CALL", "base": 93, "price": 4.3, "qty":  -17},
    {"date": "2019-09-20", "type": "CALL", "base": 87, "price": 6.45, "qty":  18}, 
    {"date": "2019-09-20", "type": "PUT", "base": 85, "price": 9.00, "qty": -10}, 
    {"date": "2019-09-20", "type": "CALL", "base": 102, "price": 1.95, "qty": 10},        

    {"date": "2019-09-23", "type": "PUT", "base": 85, "price": 8.75, "qty": 5}, 
    {"date": "2019-09-23", "type": "PUT", "base": 80, "price": 6.75, "qty":  -5}, 
    
    {"date": "2019-09-25", "type": "CALL", "base": 90, "price": 2.48, "qty": -30}, # verificada
    {"date": "2019-09-25", "type": "CALL", "base": 80, "price": 5.89, "qty": 8}, # verificada
    {"date": "2019-09-25", "type": "PUT", "base": 93, "price": 15.79, "qty": -10}, # verificada        
    {"date": "2019-09-27", "type": "CALL", "base": 80, "price": 6.76, "qty": -25}, # verificada     
    {"date": "2019-09-30", "type": "CALL", "base": 80, "price": 6.23, "qty": 25}, # verficada   
    {"date": "2019-09-30", "type": "PUT", "base": 99, "price": 15.00, "qty": -20}, # Las ejercí           
    {"date": "2019-10-02", "type": "CALL", "base": 90, "price": 3.16, "qty": 12}, # verificada        
    {"date": "2019-10-03", "type": "CALL", "base": 87, "price": 4.80, "qty": 7},  # verificada      
    {"date": "2019-10-03", "type": "CALL", "base": 75, "price": 14.30, "qty": -10}, # verificada
    {"date": "2019-10-04", "type": "CALL", "base": 90, "price": 3.75, "qty": 40}, # verificada   
    {"date": "2019-10-04", "type": "CALL", "base": 105, "price": 1.00, "qty": 47}, # verificada     
    {"date": "2019-10-04", "type": "CALL", "base": 93, "price": 2.69, "qty": 50}, # verificada
    {"date": "2019-10-07", "type": "CALL", "base": 90, "price": 3.75, "qty": 26}, # verificada   
    {"date": "2019-10-08", "type": "CALL", "base": 93, "price": 1.52, "qty": -175}, # verificada     
    {"date": "2019-10-08", "type": "CALL", "base": 90, "price": 2.29, "qty": 20}, # verificada
    {"date": "2019-10-10", "type": "CALL", "base": 75, "price": 15.00, "qty": 2},    
    {"date": "2019-09-25", "type": "CALL", "base": 99, "price": 1.50, "qty": -120},
    {"date": "2019-09-25", "type": "CALL", "base": 93, "price": 2.70, "qty": 47},    
    {"date": "2019-09-25", "type": "CALL", "base": 93, "price": 2.60, "qty": 28},  
    {"date": "2019-09-25", "type": "CALL", "base": 93, "price": 3.00, "qty": 50},
    {"date": "2019-10-04", "type": "PUT", "base": 63, "price": 0.05, "qty": 58}, 
    {"date": "2019-10-17", "type": "CALL", "base": 80, "price": 9.00, "qty": -23}, 
    {"date": "2019-10-17", "type": "PUT", "base": 80, "price": 0.01, "qty": 31},
    {"date": "2019-10-17", "type": "CALL", "base": 87, "price": 2.25, "qty": -55},    
    {"date": "2019-10-17", "type": "PUT", "base": 93, "price": 3.00, "qty": 10},
    
    # Ideas     
    #{"date": "2019-10-04", "type": "CALL", "base": 93, "price": 3.75, "qty": -100},     
    #{"date": "2019-10-04", "type": "CALL", "base": 105, "price": 2.50, "qty": -25},    
    #{"date": "2019-10-04", "type": "CALL", "base": 111, "price": 1.00, "qty": -25},  
    
    ]

getResults(trades)
# Out:
# <style  type="text/css" >
#     #T_cce25196_f0fa_11e9_a94d_080027abb6a7row0_col1 {
#             color:  green;
#         }    #T_cce25196_f0fa_11e9_a94d_080027abb6a7row1_col1 {
#             color:  green;
#         }    #T_cce25196_f0fa_11e9_a94d_080027abb6a7row2_col1 {
#             color:  green;
#         }    #T_cce25196_f0fa_11e9_a94d_080027abb6a7row3_col1 {
#             color:  green;
#         }    #T_cce25196_f0fa_11e9_a94d_080027abb6a7row4_col1 {
#             color:  green;
#         }    #T_cce25196_f0fa_11e9_a94d_080027abb6a7row5_col1 {
#             color:  green;
#         }    #T_cce25196_f0fa_11e9_a94d_080027abb6a7row6_col1 {
#             color:  green;
#         }    #T_cce25196_f0fa_11e9_a94d_080027abb6a7row7_col1 {
#             color:  green;
#         }    #T_cce25196_f0fa_11e9_a94d_080027abb6a7row8_col1 {
#             color:  green;
#         }    #T_cce25196_f0fa_11e9_a94d_080027abb6a7row9_col1 {
#             color:  green;
# ...
