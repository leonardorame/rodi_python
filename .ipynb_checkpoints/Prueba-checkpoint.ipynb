# %%
# %run 'funciones.ipynb'
current=94
trades=[
   {"date": "2019-10-16","type": "PUT", "base": 00, "price": 0.00, "qty": 0}, 
   {"date": "2019-10-16","type": "PUT", "base": 150, "price": 0.00, "qty": 0}, 
    
   {"date": "2019-10-16","type": "PUT", "base": 90, "price": 8.00, "qty": -100}, 
   {"date": "2019-10-16","type": "PUT", "base": 75, "price": 2.60, "qty": 100},      
   {"date": "2019-10-16","type": "CALL", "base": 102, "price": 11.75, "qty": -100},  
   {"date": "2019-10-16","type": "CALL", "base": 111, "price": 8.55, "qty": 100},    
   #{"date": "2019-10-16","type": "CALL", "base": 120, "price": 6.40, "qty": 150},     
    
]

getResults(trades)
# Out:
# <style  type="text/css" >
#     #T_cd763068_feed_11e9_a80f_080027abb6a7row0_col1 {
#             color:  red;
#         }    #T_cd763068_feed_11e9_a80f_080027abb6a7row1_col1 {
#             color:  red;
#         }    #T_cd763068_feed_11e9_a80f_080027abb6a7row2_col1 {
#             color:  red;
#         }    #T_cd763068_feed_11e9_a80f_080027abb6a7row3_col1 {
#             color:  red;
#         }    #T_cd763068_feed_11e9_a80f_080027abb6a7row4_col1 {
#             color:  green;
#         }    #T_cd763068_feed_11e9_a80f_080027abb6a7row5_col1 {
#             color:  green;
#         }    #T_cd763068_feed_11e9_a80f_080027abb6a7row6_col1 {
#             color:  green;
#         }    #T_cd763068_feed_11e9_a80f_080027abb6a7row7_col1 {
#             color:  green;
#         }    #T_cd763068_feed_11e9_a80f_080027abb6a7row8_col1 {
#             color:  green;
#         }    #T_cd763068_feed_11e9_a80f_080027abb6a7row9_col1 {
#             color:  green;
# ...
