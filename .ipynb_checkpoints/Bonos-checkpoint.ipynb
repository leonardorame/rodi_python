# %%
# %run 'funciones.ipynb'
import time
from IPython.display import clear_output, display
login_rodi("leonardorame", "Diana2211!")
while True:
    d=datapack()
    #print(d)
    # Vencimiento 1: CI, 3: 48hs
    af20_ci=getRealtimeData(d['d']['aTabla'], "AF20", 1)["PrecioUltimo"]
    af20_48=getRealtimeData(d['d']['aTabla'], "AF20", 3)["PrecioUltimo"]    
    ay24_ci=getRealtimeData(d['d']['aTabla'], "AY24", 1)["PrecioUltimo"]
    ay24_48=getRealtimeData(d['d']['aTabla'], "AY24", 3)["PrecioUltimo"]
    #ao20_ci=getRealtimeData(d['d']['aTabla'], "AO20", 1)["PrecioUltimo"]
    ao20_48=getRealtimeData(d['d']['aTabla'], "AO20", 3)["PrecioUltimo"]    
    clear_output(wait=True)
    print("AF20: " + af20_48)    
    print("AY24: " + ay24_48)
    print("AO20: " + ao20_ci)
    print("AY24/AO20" + ay24_48/ao20_ci)
    #print(8250*ay24_ci/100/ao20_ci*100)
    # debajo de 0.90 me conviene vender el AO20 y comprar AY24
    # arriba de 0.90 me conviene vender el AY24 y comprar AO20
    time.sleep(5)
# Out:
# cookies guardadas en archivo cookies.jar
# {u'd': {u'CantidadTotalFilas': 39, u'MensajeNro': 53420, u'TablaNombre': u'tbEspecies', u'HashCode': 576686863, u'__type': u'RODI.Contenidos.Componentes.itemEspecieResultado', u'UltimaActualizacionListaEspecies': 637122675198163820, u'aTabla': [{u'PrecioCompra': 2940.0, u'PrecioCierreAnterior': 2854.0, u'MontoOperado': 30277, u'EsEspecieConVencimientoFecha': False, u'HoraEmision': u'12:01:26', u'HoraEmisionNum': 120126, u'PrecioVenta': 3240.0, u'PrecioPromedio': 3078.3333, u'Variacion': 8.619481429572529, u'MarcaPrecioEX': False, u'PrecioPromedioPonderado': 3114.9979, u'PrecioMaximo': 3136.0, u'CantidadOperaciones': 3, u'PrecioUltimo': 3100.0, u'EstadoID': 0, u'TipoLiquidacion': 0, u'FechaVencimiento': u'/Date(-62135586000000)/', u'PrecioMinimo': 2999.0, u'FormoPrecio': True, u'CantidadNominalVenta': 100, u'PrecioCierre': 0, u'CantidadNominalCompra': 2000, u'Tendencia': -1, u'Simbolo': u'AA25', u'PrecioOperacion': 3100.0, u'VariacionOrden': 8.619481429572529, u'MensajeNro': 49749, u'VolumenNominal': 968, u'PrecioApertura': 2999.0, u'EsPrestamo': False, u'HoraCotizacion': u'12:01:26', u'VencimientoID': 1}, {u'PrecioCompra': 2943.0, u'PrecioCierreAnterior': 2950.0, u'MontoOperado': 601437, u'EsEspecieConVencimientoFecha': False, u'HoraEmision': u'12:03:08', u'HoraEmisionNum': 120308, u'PrecioVenta': 3245.5, u'PrecioPromedio': 3173.6304, u'Variacion': 10.101694915254237, u'MarcaPrecioEX': False, u'PrecioPromedioPonderado': 3157.0959, u'PrecioMaximo': 3269.5, u'CantidadOperaciones': 23, u'PrecioUltimo': 3248.0, u'EstadoID': 0, u'TipoLiquidacion': 0, u'FechaVencimiento': u'/Date(-62135586000000)/', u'PrecioMinimo': 3000.0, u'FormoPrecio': True, u'CantidadNominalVenta': 10817, u'PrecioCierre': 0, u'CantidadNominalCompra': 268, u'Tendencia': 1, u'Simbolo': u'AA25', u'PrecioOperacion': 3248.0, u'VariacionOrden': 10.101694915254237, u'MensajeNro': 53344, u'VolumenNominal': 18879, u'PrecioApertura': 3130.0, u'EsPrestamo': False, u'HoraCotizacion': u'12:03:08', u'VencimientoID': 3}, {u'PrecioCompra': 3136.5, u'PrecioCierreAnterior': 3002.0, u'MontoOperado': 19695, u'EsEspecieConVencimientoFecha': False, u'HoraEmision': u'12:02:35', u'HoraEmisionNum': 120235, u'PrecioVenta': 3230.0, u'PrecioPromedio': 3208.6667, u'Variacion': 6.595602931379081, u'MarcaPrecioEX': False, u'PrecioPromedioPonderado': 3206.1215, u'PrecioMaximo': 3225.0, u'CantidadOperaciones': 3, u'PrecioUltimo': 3200.0, u'EstadoID': 0, u'TipoLiquidacion': 0, u'FechaVencimiento': u'/Date(-62135586000000)/', u'PrecioMinimo': 3200.0, u'FormoPrecio': True, u'CantidadNominalVenta': 4797, u'PrecioCierre': 0, u'CantidadNominalCompra': 5683, u'Tendencia': -1, u'Simbolo': u'AA37', u'PrecioOperacion': 3200.0, u'VariacionOrden': 6.595602931379081, u'MensajeNro': 51561, u'VolumenNominal': 613, u'PrecioApertura': 3225.0, u'EsPrestamo': False, u'HoraCotizacion': u'12:02:35', u'VencimientoID': 1}, {u'PrecioCompra': 3200.0, u'PrecioCierreAnterior': 3124.5, u'MontoOperado': 336228, u'EsEspecieConVencimientoFecha': False, u'HoraEmision': u'12:02:35', u'HoraEmisionNum': 120235, u'PrecioVenta': 3255.5, u'PrecioPromedio': 3223.225, u'Variacion': 3.3925428068490957, u'MarcaPrecioEX': False, u'PrecioPromedioPonderado': 3239.9967, u'PrecioMaximo': 3275.0, u'CantidadOperaciones': 20, u'PrecioUltimo': 3230.5, u'EstadoID': 0, u'TipoLiquidacion': 0, u'FechaVencimiento': u'/Date(-62135586000000)/', u'PrecioMinimo': 3050.0, u'FormoPrecio': True, u'CantidadNominalVenta': 4797, u'PrecioCierre': 0, u'CantidadNominalCompra': 5683, u'Tendencia': 1, u'Simbolo': u'AA37', u'PrecioOperacion': 3230.5, u'VariacionOrden': 3.3925428068490957, u'MensajeNro': 52624, u'VolumenNominal': 10369, u'PrecioApertura': 3100.0, u'EsPrestamo': False, u'HoraCotizacion': u'12:02:35', u'VencimientoID': 3}, {u'PrecioCompra': 3700.5, u'PrecioCierreAnterior': 3505.0, u'MontoOperado': 483110, u'EsEspecieConVencimientoFecha': False, u'HoraEmision': u'12:00:11', u'HoraEmisionNum': 120011, u'PrecioVenta': 3727.0, u'PrecioPromedio': 3723.75, ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ccc8364333a6> in <module>()
#      11     ay24_ci=getRealtimeData(d['d']['aTabla'], "AY24", 1)["PrecioUltimo"]
#      12     ay24_48=getRealtimeData(d['d']['aTabla'], "AY24", 3)["PrecioUltimo"]
# ---> 13     ao20_ci=getRealtimeData(d['d']['aTabla'], "AO20", 1)["PrecioUltimo"]
#      14     ao20_48=getRealtimeData(d['d']['aTabla'], "AO20", 3)["PrecioUltimo"]
#      15     clear_output(wait=True)
#
# TypeError: 'NoneType' object has no attribute '__getitem__'
